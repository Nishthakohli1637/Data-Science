# %%
import pandas as pd

# %%
house = pd.read_csv("data/kc_house_data.csv")
titanic = pd.read_csv("data/titanic.csv")
coin = pd.read_csv("data/coin_Bitcoin.csv")
happy = pd.read_csv("data/world-happiness-report-2021.csv")

# %%
house
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
coin
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
happy
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
happy.set_index("Country name", inplace = True)

# %%
happy
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
coin.drop("Symbol", axis=1, inplace=True)

# %%
coin
# Out:
#        SNo     Name                 Date          High           Low  \
# 0        1  Bitcoin  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...                  ...           ...           ...
# 2986  2987  Bitcoin  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin  2021-07-06 23:59:59  35038.536363  33599.916169
#
#               Open         Close        Volume     Marketcap
# 0       134.444000    144.539993  0.000000e+00  1.603769e+09
# ...

# %%
coin.drop(labels = ["SNo", "Name"], axis=1, inplace=True)

# %%
coin
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# 0       144.539993  0.000000e+00  1.603769e+09
# 1       139.000000  0.000000e+00  1.542813e+09
# ...

# %%
coin.drop(columns = ["Marketcap", "Volume"], inplace=True)

# %%
coin
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close
# 0       144.539993
# 1       139.000000
# 2       116.989998
# 3       105.209999
# 4        97.750000
# ...            ...
# ...

# %%
coin[["Date", "High", "Low"]]
# Out:
#                      Date          High           Low
# 0     2013-04-29 23:59:59    147.488007    134.000000
# 1     2013-04-30 23:59:59    146.929993    134.050003
# 2     2013-05-01 23:59:59    139.889999    107.720001
# 3     2013-05-02 23:59:59    125.599998     92.281898
# 4     2013-05-03 23:59:59    108.127998     79.099998
# ...                   ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169
#
# [2991 rows x 3 columns]

# %%
happy
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
happy.drop(labels="Denmark", axis=0, inplace=True)

# %%
happy
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# ...

# %%
happy.drop(labels=["Finland","Norway"], axis=0, inplace=True)

# %%
happy
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Sweden            Western Europe         7.363
# Luxembourg        Western Europe         7.324
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# Netherlands                            0.027         7.518         7.410
# ...

# %%
happy.drop(happy.index[0:3], inplace=True)

# %%
happy
# Out:
#                  Regional indicator  Ladder score  \
# Country name
# Sweden               Western Europe         7.363
# Luxembourg           Western Europe         7.324
# New Zealand   North America and ANZ         7.277
# Austria              Western Europe         7.268
# Australia     North America and ANZ         7.183
# ...                             ...           ...
# Lesotho          Sub-Saharan Africa         3.512
# Botswana         Sub-Saharan Africa         3.467
# Rwanda           Sub-Saharan Africa         3.415
# Zimbabwe         Sub-Saharan Africa         3.145
# Afghanistan              South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Sweden                                 0.036         7.433         7.293
# Luxembourg                             0.037         7.396         7.252
# New Zealand                            0.040         7.355         7.198
# ...

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic["species"]="Human"

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic["Relative"] = titanic["sibsp"]+titanic["parch"]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic[titanic["survived"] == 1].sort_values("Relative", ascending=False)
# Out:
#      pclass  survived                                               name  \
# 641       3         1                  Asplund, Master. Edvin Rojj Felix
# 625       3         1                    Andersson, Miss. Erna Alexandra
# 646       3         1  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 643       3         1                     Asplund, Miss. Lillian Gertrud
# 111       1         1                     Fortune, Miss. Alice Elizabeth
# ..      ...       ...                                                ...
# 597       2         1                       Williams, Mr. Charles Eugene
# 598       2         1                               Wright, Miss. Marion
# 604       3         1                        Abelseth, Miss. Karen Marie
# 605       3         1                      Abelseth, Mr. Olaus Jorgensen
# 0         1         1                      Allen, Miss. Elisabeth Walton
#
#         sex age  sibsp  parch   ticket      fare        cabin embarked boat  \
# ...

# %%
solo_passengers = titanic["Relative"] == 0
titanic[solo_passengers]
# Out:
#       pclass  survived                           name     sex   age  sibsp  \
# 0          1         1  Allen, Miss. Elisabeth Walton  female    29      0
# 5          1         1            Anderson, Mr. Harry    male    48      0
# 7          1         0         Andrews, Mr. Thomas Jr    male    39      0
# 9          1         0        Artagaveytia, Mr. Ramon    male    71      0
# 12         1         1  Aubart, Mme. Leontine Pauline  female    24      0
# ...      ...       ...                            ...     ...   ...    ...
# 1302       3         0              Yousif, Mr. Wazli    male     ?      0
# 1303       3         0          Yousseff, Mr. Gerious    male     ?      0
# 1306       3         0      Zakarian, Mr. Mapriededer    male  26.5      0
# 1307       3         0            Zakarian, Mr. Ortin    male    27      0
# 1308       3         0             Zimmerman, Mr. Leo    male    29      0
#
# ...

# %%
house["price_sqft"] = house["price"]/house["sqft_living"]

# %%
house
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 0             1180      5650     1.0           0     0  ...        1180
# ...

# %%
house.sort_values("price_sqft", ascending = False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 19336  6021500970  20150407T000000   874950.0         2       1.00
# 4013    724069059  20140509T000000  2400000.0         3       2.25
# 10446  1118000320  20150508T000000  3400000.0         4       4.00
# 8623   6303400395  20150130T000000   325000.0         1       0.75
# 9314   4389200610  20141201T000000   903000.0         2       1.50
# ...           ...              ...        ...       ...        ...
# 1385   3342700465  20150123T000000   250000.0         3       1.50
# 17197  5111400086  20140512T000000   110000.0         3       1.00
# 13825  5637200450  20141017T000000   257000.0         5       2.75
# 3785    723049156  20140523T000000   149000.0         3       1.00
# 18262  2891000610  20141211T000000   148900.0         4       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 19336         1080      4000     1.0           0     0  ...        1080
# ...

# %%
coin
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close
# 0       144.539993
# 1       139.000000
# 2       116.989998
# 3       105.209999
# 4        97.750000
# ...            ...
# ...

# %%
coin.set_index("Date")
# Out:
#                              High           Low          Open         Close
# Date
# 2013-04-29 23:59:59    147.488007    134.000000    134.444000    144.539993
# 2013-04-30 23:59:59    146.929993    134.050003    144.000000    139.000000
# 2013-05-01 23:59:59    139.889999    107.720001    139.000000    116.989998
# 2013-05-02 23:59:59    125.599998     92.281898    116.379997    105.209999
# 2013-05-03 23:59:59    108.127998     79.099998    106.250000     97.750000
# ...                           ...           ...           ...           ...
# 2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177  33897.048590
# 2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362  34668.548402
# 2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866  35287.779766
# 2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430  33746.002456
# 2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655  34235.193451
#
# [2991 rows x 4 columns]

# %%
coin["change"]=coin["Close"]-coin["Open"]

# %%
coin
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close       change
# 0       144.539993    10.095993
# 1       139.000000    -5.000000
# 2       116.989998   -22.010002
# ...

# %%
coin.sort_values("change", ascending=False)
# Out:
#                      Date          High           Low          Open  \
# 2842  2021-02-08 23:59:59  46203.931437  38076.322807  38886.827290
# 2919  2021-04-26 23:59:59  54288.002155  48852.796843  49077.792363
# 2863  2021-03-01 23:59:59  49784.015290  45115.093115  45159.503053
# 2853  2021-02-19 23:59:59  56113.650547  50937.275722  51675.981285
# 2923  2021-04-30 23:59:59  57900.719988  53129.600877  53568.663584
# ...                   ...           ...           ...           ...
# 2911  2021-04-18 23:59:59  61057.456509  52829.535926  60701.886093
# 2824  2021-01-21 23:59:59  35552.679497  30250.749639  35549.397409
# 2857  2021-02-23 23:59:59  54204.929756  45290.590268  54204.929756
# 2942  2021-05-19 23:59:59  43546.116485  30681.496912  42944.975447
# 2935  2021-05-12 23:59:59  57939.362415  49150.533875  56714.533167
#
#              Close       change
# 2842  46196.463719  7309.636429
# 2919  54021.754787  4943.962424
# 2863  49631.241371  4471.738318
# ...

# %%
coin
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close       change
# 0       144.539993    10.095993
# 1       139.000000    -5.000000
# 2       116.989998   -22.010002
# ...

# %%
coin=coin.set_index("Date")

# %%
coin
# Out:
#                              High           Low          Open         Close  \
# Date
# 2013-04-29 23:59:59    147.488007    134.000000    134.444000    144.539993
# 2013-04-30 23:59:59    146.929993    134.050003    144.000000    139.000000
# 2013-05-01 23:59:59    139.889999    107.720001    139.000000    116.989998
# 2013-05-02 23:59:59    125.599998     92.281898    116.379997    105.209999
# 2013-05-03 23:59:59    108.127998     79.099998    106.250000     97.750000
# ...                           ...           ...           ...           ...
# 2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177  33897.048590
# 2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362  34668.548402
# 2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866  35287.779766
# 2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430  33746.002456
# 2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655  34235.193451
#
#                           change
# Date
# ...

# %%
coin["Delta"]=coin["High"]-coin["Low"]

# %%
coin
# Out:
#                              High           Low          Open         Close  \
# Date
# 2013-04-29 23:59:59    147.488007    134.000000    134.444000    144.539993
# 2013-04-30 23:59:59    146.929993    134.050003    144.000000    139.000000
# 2013-05-01 23:59:59    139.889999    107.720001    139.000000    116.989998
# 2013-05-02 23:59:59    125.599998     92.281898    116.379997    105.209999
# 2013-05-03 23:59:59    108.127998     79.099998    106.250000     97.750000
# ...                           ...           ...           ...           ...
# 2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177  33897.048590
# 2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362  34668.548402
# 2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866  35287.779766
# 2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430  33746.002456
# 2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655  34235.193451
#
#                           change        Delta
# ...

# %%
coin.sort_values("Delta", ascending=False)
# Out:
#                              High           Low          Open         Close  \
# Date
# 2021-05-19 23:59:59  43546.116485  30681.496912  42944.975447  37002.440466
# 2021-02-23 23:59:59  54204.929756  45290.590268  54204.929756  48824.426869
# 2021-05-12 23:59:59  57939.362415  49150.533875  56714.533167  49150.533875
# 2021-02-22 23:59:59  57533.389325  48967.565188  57532.738864  54207.319065
# 2021-05-21 23:59:59  42172.173616  33616.453884  40596.948323  37304.690671
# ...                           ...           ...           ...           ...
# 2015-09-17 23:59:59    230.285004    228.925995    229.076004    229.809998
# 2015-06-06 23:59:59    225.718994    224.378998    225.005005    225.619003
# 2015-05-28 23:59:59    237.824005    236.651993    237.257004    237.408005
# 2015-10-04 23:59:59    238.968002    237.940002    238.531006    238.259003
# 2013-08-07 23:59:59    106.750000    106.750000    106.750000    106.750000
#
#                           change         Delta
# ...

# %%
coin.sort_values("Delta", ascending=False).Delta.head(10).plot(kind = "bar")
# Out:
# <Axes: xlabel='Date'>

# %%
happy
# Out:
#                  Regional indicator  Ladder score  \
# Country name
# Sweden               Western Europe         7.363
# Luxembourg           Western Europe         7.324
# New Zealand   North America and ANZ         7.277
# Austria              Western Europe         7.268
# Australia     North America and ANZ         7.183
# ...                             ...           ...
# Lesotho          Sub-Saharan Africa         3.512
# Botswana         Sub-Saharan Africa         3.467
# Rwanda           Sub-Saharan Africa         3.415
# Zimbabwe         Sub-Saharan Africa         3.145
# Afghanistan              South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Sweden                                 0.036         7.433         7.293
# Luxembourg                             0.037         7.396         7.252
# New Zealand                            0.040         7.355         7.198
# ...

# %%
mapper = {
    "Regional indicator":"RI",
    "Ladder score":"LS"
}
happy.rename(columns = mapper)
# Out:
#                                  RI     LS  Standard error of ladder score  \
# Country name
# Sweden               Western Europe  7.363                           0.036
# Luxembourg           Western Europe  7.324                           0.037
# New Zealand   North America and ANZ  7.277                           0.040
# Austria              Western Europe  7.268                           0.036
# Australia     North America and ANZ  7.183                           0.041
# ...                             ...    ...                             ...
# Lesotho          Sub-Saharan Africa  3.512                           0.120
# Botswana         Sub-Saharan Africa  3.467                           0.074
# Rwanda           Sub-Saharan Africa  3.415                           0.068
# Zimbabwe         Sub-Saharan Africa  3.145                           0.058
# Afghanistan              South Asia  2.523                           0.038
#
# ...

# %%
mapper = {
    "Sweden":"SDN",
    "Australia":"AUS"
}
happy.rename(index = mapper)
# Out:
#                  Regional indicator  Ladder score  \
# Country name
# SDN                  Western Europe         7.363
# Luxembourg           Western Europe         7.324
# New Zealand   North America and ANZ         7.277
# Austria              Western Europe         7.268
# AUS           North America and ANZ         7.183
# ...                             ...           ...
# Lesotho          Sub-Saharan Africa         3.512
# Botswana         Sub-Saharan Africa         3.467
# Rwanda           Sub-Saharan Africa         3.415
# Zimbabwe         Sub-Saharan Africa         3.145
# Afghanistan              South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# SDN                                    0.036         7.433         7.293
# Luxembourg                             0.037         7.396         7.252
# New Zealand                            0.040         7.355         7.198
# ...

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic["sex"].replace("female", "F")
# Out:
# 0          F
# 1       male
# 2          F
# 3       male
# 4          F
#         ...
# 1304       F
# 1305       F
# 1306    male
# 1307    male
# 1308    male
# Name: sex, Length: 1309, dtype: object

# %%
titanic["sex"].replace(["female", "male"],["F", "M"])
# Out:
# 0       F
# 1       M
# 2       F
# 3       M
# 4       F
#        ..
# 1304    F
# 1305    F
# 1306    M
# 1307    M
# 1308    M
# Name: sex, Length: 1309, dtype: object
