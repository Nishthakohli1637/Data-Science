# %%
import pandas as pd

# %%
house= pd.read_csv("data/kc_house_data.csv")
titanic= pd.read_csv("data/titanic.csv")
netflix= pd.read_csv("data/netflix_titles.csv", sep="|")

# %%
house
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
netflix
# Out:
#       Unnamed: 0 show_id     type                  title         director  \
# 0              0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1              1      s2  TV Show          Blood & Water              NaN
# 2              2      s3  TV Show              Ganglands  Julien Leclercq
# 3              3      s4  TV Show  Jailbirds New Orleans              NaN
# 4              4      s5  TV Show           Kota Factory              NaN
# ...          ...     ...      ...                    ...              ...
# 8802        8802   s8803    Movie                 Zodiac    David Fincher
# 8803        8803   s8804  TV Show            Zombie Dumb              NaN
# 8804        8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805        8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806        8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# ...

# %%
netflix
# Out:
#       Unnamed: 0 show_id     type                  title         director  \
# 0              0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1              1      s2  TV Show          Blood & Water              NaN
# 2              2      s3  TV Show              Ganglands  Julien Leclercq
# 3              3      s4  TV Show  Jailbirds New Orleans              NaN
# 4              4      s5  TV Show           Kota Factory              NaN
# ...          ...     ...      ...                    ...              ...
# 8802        8802   s8803    Movie                 Zodiac    David Fincher
# 8803        8803   s8804  TV Show            Zombie Dumb              NaN
# 8804        8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805        8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806        8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# ...

# %%
df=titanic

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.sex
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4       female
#          ...
# 1304    female
# 1305    female
# 1306      male
# 1307      male
# 1308      male
# Name: sex, Length: 1309, dtype: object

# %%
df.sex=="female"
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 1304     True
# 1305     True
# 1306    False
# 1307    False
# 1308    False
# Name: sex, Length: 1309, dtype: bool

# %%
df[df.sex=="female"]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 2          1         0                     Allison, Miss. Helen Loraine
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic[titanic.survived==1]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1261       3         1                           Turkula, Mrs. (Hedwig)
# 1277       3         1                             Vartanian, Mr. David
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked   boat  \
# ...

# %%
titanic[titanic.age=="18"]
# Out:
#       pclass  survived                                               name  \
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 198        1         1  Marvin, Mrs. Daniel Warner (Mary Graham Carmic...
# 228        1         0         Penasco y Castellana, Mr. Victor de Satode
# 250        1         1                         Ryerson, Miss. Emily Borie
# 270        1         1     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)
# 289        1         1                                Taussig, Miss. Ruth
# 326        2         0                         Andrew, Mr. Edgardo Samuel
# 331        2         0                           Bailey, Mr. Percy Andrew
# 386        2         0                          Davies, Mr. Charles Henry
# 394        2         0                                Dibden, Mr. William
# 395        2         1                                Doling, Miss. Elsie
# 405        2         0                          Fahlstrom, Mr. Arne Jonas
# ...

# %%
titanic[titanic.pclass!=1]
# Out:
#       pclass  survived                                   name     sex   age  \
# 323        2         0                    Abelson, Mr. Samuel    male    30
# 324        2         1  Abelson, Mrs. Samuel (Hannah Wizosky)  female    28
# 325        2         0         Aldworth, Mr. Charles Augustus    male    30
# 326        2         0             Andrew, Mr. Edgardo Samuel    male    18
# 327        2         0               Andrew, Mr. Frank Thomas    male    25
# ...      ...       ...                                    ...     ...   ...
# 1304       3         0                   Zabour, Miss. Hileni  female  14.5
# 1305       3         0                  Zabour, Miss. Thamine  female     ?
# 1306       3         0              Zakarian, Mr. Mapriededer    male  26.5
# 1307       3         0                    Zakarian, Mr. Ortin    male    27
# 1308       3         0                     Zimmerman, Mr. Leo    male    29
#
# ...

# %%
house[house.price > 50000]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
house[house.bedrooms >= 10]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 19254  8812401450  20141229T000000   660000.0        10       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 8757          3000      4960     2.0           0     0  ...      7
# 13314         4590     10920     1.0           0     2  ...      9
# 15161         3610     11914     2.0           0     0  ...      7
# 15870         1620      6000     1.0           0     0  ...      7
# 19254         2920      3745     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 8757         2400            600      1918          1999    98106  47.5560
# ...

# %%
house[house.bedrooms.between(8, 10)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1660   9126101740  20141204T000000   490000.0         8       5.00
# 4035    685000115  20141007T000000  2150000.0         8       6.00
# 4067   7226500100  20150219T000000   373000.0         8       3.00
# 4096   1997200215  20140507T000000   599999.0         9       4.50
# 4235   2902200015  20150106T000000   700000.0         9       3.00
# 6079   9822700190  20140808T000000  1280000.0         9       4.50
# 6174   1873400020  20140703T000000   340000.0         8       2.75
# 8546    424049043  20140811T000000   450000.0         9       7.50
# 9077   6746700615  20150318T000000   700000.0         8       2.50
# 9452   2769600590  20141016T000000   900000.0         8       4.00
# 10958  1652500060  20140711T000000  1650000.0         8       2.75
# 12885  8813400155  20141219T000000   808000.0         8       3.75
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# ...

# %%
house.bedrooms.between(8, 10)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Name: bedrooms, Length: 21613, dtype: bool

# %%
house.bedrooms.between(8, 10).value_counts()
# Out:
# False    21591
# True        22
# Name: bedrooms, dtype: int64

# %%
house[house.bedrooms.between(8, 10)].bedrooms
# Out:
# 1660      8
# 4035      8
# 4067      8
# 4096      9
# 4235      9
# 6079      9
# 6174      8
# 8546      9
# 9077      8
# 9452      8
# 10958     8
# 12885     8
# 13314    10
# 15070     8
# 15161    10
# 15670     8
# 16844     9
# 17235     8
# 18443     9
# 18477     8
# 19254    10
# 19302     8
# Name: bedrooms, dtype: int64

# %%
house[house.bedrooms.between(8, 10)].bedrooms.value_counts()
# Out:
# 8     13
# 9      6
# 10     3
# Name: bedrooms, dtype: int64

# %%
house[house.bedrooms.between(8, 10)].bedrooms.value_counts().plot()
# Out:
# <Axes: >

# %%
house[house.bedrooms.between(8, 10)].bedrooms.value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='bedrooms'>

# %%
netflix
# Out:
#       Unnamed: 0 show_id     type                  title         director  \
# 0              0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1              1      s2  TV Show          Blood & Water              NaN
# 2              2      s3  TV Show              Ganglands  Julien Leclercq
# 3              3      s4  TV Show  Jailbirds New Orleans              NaN
# 4              4      s5  TV Show           Kota Factory              NaN
# ...          ...     ...      ...                    ...              ...
# 8802        8802   s8803    Movie                 Zodiac    David Fincher
# 8803        8803   s8804  TV Show            Zombie Dumb              NaN
# 8804        8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805        8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806        8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# ...

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    8807 non-null   int64
#  1   show_id       8807 non-null   object
#  2   type          8807 non-null   object
#  3   title         8807 non-null   object
#  4   director      6173 non-null   object
#  5   cast          7982 non-null   object
#  6   country       7976 non-null   object
#  7   date_added    8797 non-null   object
#  8   release_year  8807 non-null   int64
#  9   rating        8803 non-null   object
#  10  duration      8804 non-null   object
#  11  listed_in     8807 non-null   object
#  12  description   8807 non-null   object
# dtypes: int64(2), object(11)
# memory usage: 894.6+ KB

# %%
netflix[netflix.country == "India"]
# Out:
#       Unnamed: 0 show_id     type                          title  \
# 4              4      s5  TV Show                   Kota Factory
# 24            24     s25    Movie                          Jeans
# 39            39     s40  TV Show                   Chhota Bheem
# 50            50     s51  TV Show                  Dharmakshetra
# 66            66     s67  TV Show  Raja Rasoi Aur Anya Kahaniyan
# ...          ...     ...      ...                            ...
# 8773        8773   s8774    Movie            Yanda Kartavya Aahe
# 8775        8775   s8776  TV Show                Yeh Meri Family
# 8798        8798   s8799    Movie                       Zed Plus
# 8799        8799   s8800    Movie                          Zenda
# 8806        8806   s8807    Movie                         Zubaan
#
#                      director  \
# 4                         NaN
# 24                 S. Shankar
# 39                        NaN
# 50                        NaN
# ...

# %%
netflix.country
# Out:
# 0       United States
# 1        South Africa
# 2                 NaN
# 3                 NaN
# 4               India
#             ...
# 8802    United States
# 8803              NaN
# 8804    United States
# 8805    United States
# 8806            India
# Name: country, Length: 8807, dtype: object

# %%
country = ["India", "Japan", "South Korea", "Canada"]
netflix[netflix.country.isin(country)]
# Out:
#       Unnamed: 0 show_id     type  \
# 4              4      s5  TV Show
# 24            24     s25    Movie
# 39            39     s40  TV Show
# 50            50     s51  TV Show
# 51            51     s52    Movie
# ...          ...     ...      ...
# 8773        8773   s8774    Movie
# 8775        8775   s8776  TV Show
# 8798        8798   s8799    Movie
# 8799        8799   s8800    Movie
# 8806        8806   s8807    Movie
#
#                                                   title  \
# 4                                          Kota Factory
# 24                                                Jeans
# 39                                         Chhota Bheem
# 50                                        Dharmakshetra
# 51    InuYasha the Movie 2: The Castle Beyond the Lo...
# ...                                                 ...
# 8773                                Yanda Kartavya Aahe
# 8775                                    Yeh Meri Family
# ...

# %%
netflix[netflix.country.isin(country)].country.value_counts()
# Out:
# India          972
# Japan          245
# South Korea    199
# Canada         181
# Name: country, dtype: int64

# %%
women = titanic.sex == "female"
died = titanic.survived == 0
titanic[women & died]
# Out:
#       pclass  survived                                               name  \
# 2          1         0                       Allison, Miss. Helen Loraine
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 105        1         0                           Evans, Miss. Edith Corse
# 169        1         0                         Isham, Miss. Ann Elizabeth
# 286        1         0             Straus, Mrs. Isidor (Rosalie Ida Blun)
# ...      ...       ...                                                ...
# 1273       3         0                 Vander Planke, Miss. Augusta Maria
# 1276       3         0  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 1279       3         0               Vestrom, Miss. Hulda Amanda Adolfina
# 1304       3         0                               Zabour, Miss. Hileni
# 1305       3         0                              Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch    ticket      fare    cabin embarked boat  \
# ...

# %%
men = titanic.sex == "male"
died = titanic.survived == 0
titanic[men & died]
# Out:
#       pclass  survived                                  name   sex   age  \
# 3          1         0  Allison, Mr. Hudson Joshua Creighton  male    30
# 7          1         0                Andrews, Mr. Thomas Jr  male    39
# 9          1         0               Artagaveytia, Mr. Ramon  male    71
# 10         1         0                Astor, Col. John Jacob  male    47
# 15         1         0                   Baumann, Mr. John D  male     ?
# ...      ...       ...                                   ...   ...   ...
# 1302       3         0                     Yousif, Mr. Wazli  male     ?
# 1303       3         0                 Yousseff, Mr. Gerious  male     ?
# 1306       3         0             Zakarian, Mr. Mapriededer  male  26.5
# 1307       3         0                   Zakarian, Mr. Ortin  male    27
# 1308       3         0                    Zimmerman, Mr. Leo  male    29
#
#       sibsp  parch    ticket     fare    cabin embarked boat body  \
# ...

# %%
house[(house["waterfront"] == 1) & (house["price"] < 5000000)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 49      822039084  20150311T000000  1350000.0         3       2.50
# 230    8096000060  20150413T000000   655000.0         2       1.75
# 246    2025069065  20140929T000000  2400000.0         4       2.50
# 264    2123039032  20141027T000000   369900.0         1       0.75
# 300    3225069065  20140624T000000  3075000.0         4       5.00
# ...           ...              ...        ...       ...        ...
# 19984  2025069140  20150317T000000  1898000.0         3       2.50
# 20325   518500480  20140811T000000  3000000.0         3       3.50
# 20767  8043700105  20150417T000000  2300000.0         4       4.00
# 21201   518500460  20141008T000000  2230000.0         3       3.50
# 21576  9253900271  20150107T000000  3567000.0         5       4.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 49            2753     65005     1.0           1     2  ...      9
# ...

# %%
house[(house["waterfront"] == 1) & (house["price"] < 5000000)].waterfront.value_counts()
# Out:
# 1    160
# Name: waterfront, dtype: int64

# %%
house.waterfront.value_counts()
# Out:
# 0    21450
# 1      163
# Name: waterfront, dtype: int64

# %%
quality = house["grade"] >=11
view = house["view"] == 4
space = house["sqft_living"] <=3000
house[quality & view & space]
# Out:
#              id             date      price  bedrooms  bathrooms  sqft_living  \
# 4013  724069059  20140509T000000  2400000.0         3       2.25         3000
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 4013     11665     1.5           1     4  ...     11        3000
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 4013              0      2001             0    98075  47.5884 -122.086
#
#       sqft_living15  sqft_lot15
# 4013           3000       15959
#
# [1 rows x 21 columns]

# %%
quality = house["grade"] >=11
view = house["view"] == 4
space = house["sqft_living"] <=3000
house[quality | view & space]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 70     1525059190  20140912T000000  1040000.0         5       3.25
# 153    7855801670  20150401T000000  2250000.0         4       3.25
# 230    8096000060  20150413T000000   655000.0         2       1.75
# 264    2123039032  20141027T000000   369900.0         1       0.75
# ...           ...              ...        ...       ...        ...
# 21532   324069112  20140617T000000  1325000.0         4       4.00
# 21548  8835770330  20140819T000000  1057000.0         2       1.50
# 21551  1561750040  20141224T000000  1375000.0         5       4.50
# 21590  7430200100  20140514T000000  1222500.0         4       3.50
# 21600   249000205  20141015T000000  1537000.0         5       3.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 5             5420    101930     1.0           0     0  ...     11
# ...

# %%
women =titanic.sex == "female"
titanic[~women]
# Out:
#       pclass  survived                                  name   sex     age  \
# 1          1         1        Allison, Master. Hudson Trevor  male  0.9167
# 3          1         0  Allison, Mr. Hudson Joshua Creighton  male      30
# 5          1         1                   Anderson, Mr. Harry  male      48
# 7          1         0                Andrews, Mr. Thomas Jr  male      39
# 9          1         0               Artagaveytia, Mr. Ramon  male      71
# ...      ...       ...                                   ...   ...     ...
# 1302       3         0                     Yousif, Mr. Wazli  male       ?
# 1303       3         0                 Yousseff, Mr. Gerious  male       ?
# 1306       3         0             Zakarian, Mr. Mapriededer  male    26.5
# 1307       3         0                   Zakarian, Mr. Ortin  male      27
# 1308       3         0                    Zimmerman, Mr. Leo  male      29
#
#       sibsp  parch    ticket     fare    cabin embarked boat body  \
# ...

# %%
titanic[~women].sex.value_counts()
# Out:
# male    843
# Name: sex, dtype: int64

# %%
netflix[netflix['country'].isna()]
# Out:
#       Unnamed: 0 show_id     type                                title  \
# 2              2      s3  TV Show                            Ganglands
# 3              3      s4  TV Show                Jailbirds New Orleans
# 5              5      s6  TV Show                        Midnight Mass
# 6              6      s7    Movie     My Little Pony: A New Generation
# 10            10     s11  TV Show  Vendetta: Truth, Lies and The Mafia
# ...          ...     ...      ...                                  ...
# 8718        8718   s8719    Movie               Westside vs. the World
# 8759        8759   s8760    Movie               World's Weirdest Homes
# 8783        8783   s8784  TV Show                                 Yoko
# 8785        8785   s8786  TV Show                                  YOM
# 8803        8803   s8804  TV Show                          Zombie Dumb
#
#                            director  \
# 2                   Julien Leclercq
# 3                               NaN
# ...

# %%
netflix[(netflix['country'].isna()) & (netflix['cast'].isna()) | (netflix['director'].notna())]
# Out:
#       Unnamed: 0 show_id     type                             title  \
# 0              0      s1    Movie              Dick Johnson Is Dead
# 2              2      s3  TV Show                         Ganglands
# 3              3      s4  TV Show             Jailbirds New Orleans
# 5              5      s6  TV Show                     Midnight Mass
# 6              6      s7    Movie  My Little Pony: A New Generation
# ...          ...     ...      ...                               ...
# 8802        8802   s8803    Movie                            Zodiac
# 8803        8803   s8804  TV Show                       Zombie Dumb
# 8804        8804   s8805    Movie                        Zombieland
# 8805        8805   s8806    Movie                              Zoom
# 8806        8806   s8807    Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 2                   Julien Leclercq
# 3                               NaN
# ...

# %%
titanic[women].survived.value_counts()
# Out:
# 1    339
# 0    127
# Name: survived, dtype: int64

# %%
titanic[women].survived.value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='survived'>

# %%
titanic[~women].survived.value_counts()
# Out:
# 0    682
# 1    161
# Name: survived, dtype: int64

# %%
titanic[-women].survived.value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='survived'>
