# %% [markdown]
# # PANDAS

# %% [markdown]
# <img src = "https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/1200px-Pandas_logo.svg.png">

# %%
import pandas as pd

# %%
coin = pd.read_csv("data/coin_Bitcoin.csv")

# %%
coin
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %% [markdown]
# # IT IS A TYPE OF DATATYPE IN PANDAS

# %%
type(coin)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # IT WILL GIVE THE TOP ELEMENTS IN DATA

# %%
coin.head(10)
# Out:
#    SNo     Name Symbol                 Date        High         Low  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999  107.720001
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  125.599998   92.281898
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  108.127998   79.099998
# 5    6  Bitcoin    BTC  2013-05-04 23:59:59  115.000000   92.500000
# 6    7  Bitcoin    BTC  2013-05-05 23:59:59  118.800003  107.142998
# 7    8  Bitcoin    BTC  2013-05-06 23:59:59  124.663002  106.639999
# 8    9  Bitcoin    BTC  2013-05-07 23:59:59  113.444000   97.699997
# 9   10  Bitcoin    BTC  2013-05-08 23:59:59  115.779999  109.599998
#
#          Open       Close  Volume     Marketcap
# 0  134.444000  144.539993     0.0  1.603769e+09
# 1  144.000000  139.000000     0.0  1.542813e+09
# 2  139.000000  116.989998     0.0  1.298955e+09
# ...

# %% [markdown]
# # IT WILL GIVE THE BOTTOM ELEMENTS IN DATA

# %%
coin.tail()
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
#               Open         Close        Volume     Marketcap
# 2986  33549.600177  33897.048590  3.872897e+10  6.354508e+11
# 2987  33854.421362  34668.548402  2.438396e+10  6.499397e+11
# 2988  34665.564866  35287.779766  2.492431e+10  6.615748e+11
# 2989  35284.344430  33746.002456  2.672155e+10  6.326962e+11
# 2990  33723.509655  34235.193451  2.650126e+10  6.418992e+11

# %% [markdown]
# # IT WILL GIVE ROWS & COLUMNS IN DATA

# %%
coin.shape
# Out:
# (2991, 10)

# %%
coin.columns
# Out:
# Index(['SNo', 'Name', 'Symbol', 'Date', 'High', 'Low', 'Open', 'Close',
#        'Volume', 'Marketcap'],
#       dtype='object')

# %%
type(coin.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
coin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2991 entries, 0 to 2990
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SNo        2991 non-null   int64
#  1   Name       2991 non-null   object
#  2   Symbol     2991 non-null   object
#  3   Date       2991 non-null   object
#  4   High       2991 non-null   float64
#  5   Low        2991 non-null   float64
#  6   Open       2991 non-null   float64
#  7   Close      2991 non-null   float64
#  8   Volume     2991 non-null   float64
#  9   Marketcap  2991 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 233.8+ KB

# %%
 coin.dtypes
# Out:
# SNo            int64
# Name          object
# Symbol        object
# Date          object
# High         float64
# Low          float64
# Open         float64
# Close        float64
# Volume       float64
# Marketcap    float64
# dtype: object

# %% [markdown]
# # WHEN DATA IS NOT SEPARATED BY COMMAS

# %%
netflix = pd.read_csv("data/netflix_titles.csv", sep="|")

# %%
netflix
# Out:
#       Unnamed: 0 show_id     type                  title         director  \
# 0              0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1              1      s2  TV Show          Blood & Water              NaN
# 2              2      s3  TV Show              Ganglands  Julien Leclercq
# 3              3      s4  TV Show  Jailbirds New Orleans              NaN
# 4              4      s5  TV Show           Kota Factory              NaN
# ...          ...     ...      ...                    ...              ...
# 8802        8802   s8803    Movie                 Zodiac    David Fincher
# 8803        8803   s8804  TV Show            Zombie Dumb              NaN
# 8804        8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805        8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806        8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# ...

# %%
house = pd.read_csv("data/kc_house_data.csv")

# %%
house
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
house.min()
# Out:
# id                       1000102
# date             20140502T000000
# price                    75000.0
# bedrooms                       0
# bathrooms                    0.0
# sqft_living                  290
# sqft_lot                     520
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      1
# grade                          1
# sqft_above                   290
# sqft_basement                  0
# yr_built                    1900
# yr_renovated                   0
# zipcode                    98001
# lat                      47.1559
# long                    -122.519
# sqft_living15                399
# sqft_lot15                   651
# dtype: object

# %%
 type(house.min())
# Out:
# pandas.core.series.Series

# %%
house.max()
# Out:
# id                    9900000190
# date             20150527T000000
# price                  7700000.0
# bedrooms                      33
# bathrooms                    8.0
# sqft_living                13540
# sqft_lot                 1651359
# floors                       3.5
# waterfront                     1
# view                           4
# condition                      5
# grade                         13
# sqft_above                  9410
# sqft_basement               4820
# yr_built                    2015
# yr_renovated                2015
# zipcode                    98199
# lat                      47.7776
# long                    -121.315
# sqft_living15               6210
# sqft_lot15                871200
# dtype: object

# %%
type(house.max())
# Out:
# pandas.core.series.Series

# %%
house.sum()
# Out:
# id                                                  98994056770455
# date             20141013T00000020141209T00000020150225T0000002...
# price                                                11672925008.0
# bedrooms                                                     72854
# bathrooms                                                 45706.25
# sqft_living                                               44952873
# sqft_lot                                                 326506890
# floors                                                     32296.5
# waterfront                                                     163
# view                                                          5064
# condition                                                    73688
# grade                                                       165488
# sqft_above                                                38652488
# sqft_basement                                              6300385
# ...

# %%
house.sum(numeric_only = True)
# Out:
# id               9.899406e+13
# price            1.167293e+10
# bedrooms         7.285400e+04
# bathrooms        4.570625e+04
# sqft_living      4.495287e+07
# sqft_lot         3.265069e+08
# floors           3.229650e+04
# waterfront       1.630000e+02
# view             5.064000e+03
# condition        7.368800e+04
# grade            1.654880e+05
# sqft_above       3.865249e+07
# sqft_basement    6.300385e+06
# yr_built         4.259933e+07
# yr_renovated     1.824186e+06
# zipcode          2.119759e+09
# lat              1.027915e+06
# long            -2.641409e+06
# sqft_living15    4.293536e+07
# sqft_lot15       2.759646e+08
# dtype: float64

# %%
5.064000e+03
# Out:
# 5064.0

# %%
house.tail(10).sum()
# Out:
# id                                                     42270012603
# date             20140825T00000020150126T00000020141014T0000002...
# price                                                    4916536.0
# bedrooms                                                        31
# bathrooms                                                     22.0
# sqft_living                                                  18580
# sqft_lot                                                     32937
# floors                                                        22.0
# waterfront                                                       0
# view                                                             0
# condition                                                       30
# grade                                                           80
# sqft_above                                                   17540
# sqft_basement                                                 1040
# ...

# %%
house.tail(10).sum(numeric_only = True)
# Out:
# id               4.227001e+10
# price            4.916536e+06
# bedrooms         3.100000e+01
# bathrooms        2.200000e+01
# sqft_living      1.858000e+04
# sqft_lot         3.293700e+04
# floors           2.200000e+01
# waterfront       0.000000e+00
# view             0.000000e+00
# condition        3.000000e+01
# grade            8.000000e+01
# sqft_above       1.754000e+04
# sqft_basement    1.040000e+03
# yr_built         2.009200e+04
# yr_renovated     0.000000e+00
# zipcode          9.810810e+05
# lat              4.756865e+02
# long            -1.222518e+03
# sqft_living15    1.638000e+04
# sqft_lot15       3.380900e+04
# dtype: float64

# %%
house
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
house.mean()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_11060\592001825.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   house.mean()
# id               4.580302e+09
# price            5.400881e+05
# bedrooms         3.370842e+00
# bathrooms        2.114757e+00
# sqft_living      2.079900e+03
# sqft_lot         1.510697e+04
# floors           1.494309e+00
# waterfront       7.541757e-03
# view             2.343034e-01
# condition        3.409430e+00
# grade            7.656873e+00
# sqft_above       1.788391e+03
# sqft_basement    2.915090e+02
# yr_built         1.971005e+03
# yr_renovated     8.440226e+01
# zipcode          9.807794e+04
# lat              4.756005e+01
# long            -1.222139e+02
# sqft_living15    1.986552e+03
# sqft_lot15       1.276846e+04
# ...

# %%
house.median(numeric_only = True)
# Out:
# id               3.904930e+09
# price            4.500000e+05
# bedrooms         3.000000e+00
# bathrooms        2.250000e+00
# sqft_living      1.910000e+03
# sqft_lot         7.618000e+03
# floors           1.500000e+00
# waterfront       0.000000e+00
# view             0.000000e+00
# condition        3.000000e+00
# grade            7.000000e+00
# sqft_above       1.560000e+03
# sqft_basement    0.000000e+00
# yr_built         1.975000e+03
# yr_renovated     0.000000e+00
# zipcode          9.806500e+04
# lat              4.757180e+01
# long            -1.222300e+02
# sqft_living15    1.840000e+03
# sqft_lot15       7.620000e+03
# dtype: float64

# %%
house.mode()
# Out:
#             id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  795000620.0  20140623T000000  350000.0       3.0        2.5       1300.0
# 1          NaN              NaN  450000.0       NaN        NaN          NaN
# 2          NaN              NaN       NaN       NaN        NaN          NaN
# 3          NaN              NaN       NaN       NaN        NaN          NaN
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0    5000.0     1.0         0.0   0.0  ...    7.0      1300.0            0.0
# 1       NaN     NaN         NaN   NaN  ...    NaN         NaN            NaN
# 2       NaN     NaN         NaN   NaN  ...    NaN         NaN            NaN
# 3       NaN     NaN         NaN   NaN  ...    NaN         NaN            NaN
#
#    yr_built  yr_renovated  zipcode      lat    long  sqft_living15  sqft_lot15
# 0    2014.0           0.0  98103.0  47.5322 -122.29         1540.0      5000.0
# ...

# %%
house.mode(numeric_only = True)
# Out:
#             id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  795000620.0  350000.0       3.0        2.5       1300.0    5000.0     1.0
# 1          NaN  450000.0       NaN        NaN          NaN       NaN     NaN
# 2          NaN       NaN       NaN        NaN          NaN       NaN     NaN
# 3          NaN       NaN       NaN        NaN          NaN       NaN     NaN
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0         0.0   0.0        3.0    7.0      1300.0            0.0    2014.0
# 1         NaN   NaN        NaN    NaN         NaN            NaN       NaN
# 2         NaN   NaN        NaN    NaN         NaN            NaN       NaN
# 3         NaN   NaN        NaN    NaN         NaN            NaN       NaN
#
#    yr_renovated  zipcode      lat    long  sqft_living15  sqft_lot15
# 0           0.0  98103.0  47.5322 -122.29         1540.0      5000.0
# ...

# %%
house.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
house.count()
# Out:
# id               21613
# date             21613
# price            21613
# bedrooms         21613
# bathrooms        21613
# sqft_living      21613
# sqft_lot         21613
# floors           21613
# waterfront       21613
# view             21613
# condition        21613
# grade            21613
# sqft_above       21613
# sqft_basement    21613
# yr_built         21613
# yr_renovated     21613
# zipcode          21613
# lat              21613
# long             21613
# sqft_living15    21613
# sqft_lot15       21613
# dtype: int64

# %% [markdown]
# # SERIES IN PANDAS (TO FIND DATA OF PARTICULAR ROW / COLUMN)

# %%
house
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
house.bathrooms
# Out:
# 0        1.00
# 1        2.25
# 2        1.00
# 3        3.00
# 4        2.00
#          ...
# 21608    2.50
# 21609    2.50
# 21610    0.75
# 21611    2.50
# 21612    0.75
# Name: bathrooms, Length: 21613, dtype: float64

# %%
house.bathrooms.min()
# Out:
# 0.0

# %%
house.bathrooms.max()
# Out:
# 8.0

# %%
house.bathrooms.sum()
# Out:
# 45706.25

# %%
house.bathrooms.tail(20)
# Out:
# 21593    3.75
# 21594    2.75
# 21595    2.25
# 21596    2.75
# 21597    3.25
# 21598    2.50
# 21599    3.00
# 21600    3.75
# 21601    2.50
# 21602    1.75
# 21603    2.50
# 21604    2.00
# 21605    2.50
# 21606    3.50
# 21607    2.50
# 21608    2.50
# 21609    2.50
# 21610    0.75
# 21611    2.50
# 21612    0.75
# Name: bathrooms, dtype: float64

# %%
type(house.bathrooms)
# Out:
# pandas.core.series.Series

# %%
house.bathrooms.unique()
# Out:
# array([1.  , 2.25, 3.  , 2.  , 4.5 , 1.5 , 2.5 , 1.75, 2.75, 3.25, 4.  ,
#        3.5 , 0.75, 4.75, 5.  , 4.25, 3.75, 0.  , 1.25, 5.25, 6.  , 0.5 ,
#        5.5 , 6.75, 5.75, 8.  , 7.5 , 7.75, 6.25, 6.5 ])

# %%
house.bathrooms.nlargest()
# Out:
# 7252     8.00
# 12777    8.00
# 9254     7.75
# 8546     7.50
# 4024     6.75
# Name: bathrooms, dtype: float64

# %%
house.bathrooms.nlargest(10)
# Out:
# 7252     8.00
# 12777    8.00
# 9254     7.75
# 8546     7.50
# 4024     6.75
# 8092     6.75
# 20578    6.50
# 21506    6.50
# 14556    6.25
# 18302    6.25
# Name: bathrooms, dtype: float64

# %%
house.nlargest(n=10, columns=["price"])
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
# 8092  1924059029  20140617T000000  4668000.0         5       6.75
# 2626  7738500731  20140815T000000  4500000.0         5       5.50
# 8638  3835500195  20140618T000000  4489000.0         4       3.00
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252        12050     27600     2.5           0     3  ...     13        8570
# 3914        10040     37325     2.0           1     2  ...     11        7680
# ...

# %%
house.sqft_living.nlargest(10)
# Out:
# 12777    13540
# 7252     12050
# 3914     10040
# 9254      9890
# 8092      9640
# 4411      9200
# 14556     8670
# 18302     8020
# 1164      8010
# 1448      8000
# Name: sqft_living, dtype: int64

# %%
house.bathrooms.value_counts()
# Out:
# 2.50    5380
# 1.00    3852
# 1.75    3048
# 2.25    2047
# 2.00    1930
# 1.50    1446
# 2.75    1185
# 3.00     753
# 3.50     731
# 3.25     589
# 3.75     155
# 4.00     136
# 4.50     100
# 4.25      79
# 0.75      72
# 4.75      23
# 5.00      21
# 5.25      13
# 0.00      10
# 5.50      10
# 1.25       9
# 6.00       6
# 0.50       4
# 5.75       4
# 6.75       2
# 8.00       2
# 6.25       2
# 6.50       2
# 7.50       1
# 7.75       1
# Name: bathrooms, dtype: int64

# %%
house.bedrooms
# Out:
# 0        3
# 1        3
# 2        2
# 3        4
# 4        3
#         ..
# 21608    3
# 21609    4
# 21610    2
# 21611    3
# 21612    2
# Name: bedrooms, Length: 21613, dtype: int64

# %%
house.bedrooms.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 21613 entries, 0 to 21612
# Series name: bedrooms
# Non-Null Count  Dtype
# --------------  -----
# 21613 non-null  int64
# dtypes: int64(1)
# memory usage: 169.0 KB

# %%
house.bedrooms.max()
# Out:
# 33

# %%
house.bedrooms.value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
import pandas as pd

# %%
house = pd.read_csv("data/kc_house_data.csv")

# %%
house
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
house.bedrooms.value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
house.bedrooms.value_counts().plot()
# Out:
# <Axes: >

# %%
house.bedrooms.value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='bedrooms'>

# %%
house.sort_values("price")
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1149   3421079032  20150217T000000    75000.0         1       0.00
# 15293    40000362  20140506T000000    78000.0         2       1.00
# 465    8658300340  20140523T000000    80000.0         1       0.75
# 16198  3028200080  20150324T000000    81000.0         2       1.00
# 8274   3883800011  20141105T000000    82000.0         3       1.00
# ...           ...              ...        ...       ...        ...
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1149           670     43377     1.0           0     0  ...      3
# ...

# %%
house.sort_values("price", ascending=False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 7252   6762700020  20141013T000000  7700000.0         6       8.00
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 9254   9208900037  20140919T000000  6885000.0         6       7.75
# 4411   2470100110  20140804T000000  5570000.0         5       5.75
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# ...           ...              ...        ...       ...        ...
# 8274   3883800011  20141105T000000    82000.0         3       1.00
# 16198  3028200080  20150324T000000    81000.0         2       1.00
# 465    8658300340  20140523T000000    80000.0         1       0.75
# 15293    40000362  20140506T000000    78000.0         2       1.00
# 1149   3421079032  20150217T000000    75000.0         1       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 7252         12050     27600     2.5           0     3  ...     13
# ...

# %%
house.sort_values(["bedrooms", "bathrooms"], ascending=False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# ...           ...              ...        ...       ...        ...
# 6994   2954400190  20140624T000000  1295650.0         0       0.00
# 9773   3374500520  20150429T000000   355000.0         0       0.00
# 9854   7849202190  20141223T000000   235000.0         0       0.00
# 14423  9543000205  20150413T000000   139950.0         0       0.00
# 19452  3980300371  20140926T000000   142000.0         0       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# ...

# %%
netflix.sort_values("title")
# Out:
#       Unnamed: 0 show_id     type                          title  \
# 2036        2036   s2037    Movie                         #Alive
# 2304        2304   s2305    Movie  #AnneFrank - Parallel Stories
# 2481        2481   s2482    Movie              #FriendButMarried
# 2324        2324   s2325    Movie            #FriendButMarried 2
# 5973        5973   s5974    Movie                          #Roxy
# ...          ...     ...      ...                            ...
# 6177        6177   s6178  TV Show                       忍者ハットリくん
# 4914        4914   s4915  TV Show                           海的儿子
# 7101        7101   s7102  TV Show                           마녀사냥
# 5022        5022   s5023    Movie                        반드시 잡는다
# 7108        7108   s7109    Movie            최강전사 미니특공대 : 영웅의 탄생
#
#                          director  \
# 2036                       Cho Il
# 2304  Sabina Fedeli, Anna Migotto
# 2481                Rako Prijanto
# 2324                Rako Prijanto
# ...

# %%
netflix.sort_values("title", key = lambda col : col.str.lower())
# Out:
#       Unnamed: 0 show_id     type                          title  \
# 2036        2036   s2037    Movie                         #Alive
# 2304        2304   s2305    Movie  #AnneFrank - Parallel Stories
# 2666        2666   s2667  TV Show                       #blackAF
# 5972        5972   s5973    Movie               #cats_the_mewvie
# 2481        2481   s2482    Movie              #FriendButMarried
# ...          ...     ...      ...                            ...
# 6177        6177   s6178  TV Show                       忍者ハットリくん
# 4914        4914   s4915  TV Show                           海的儿子
# 7101        7101   s7102  TV Show                           마녀사냥
# 5022        5022   s5023    Movie                        반드시 잡는다
# 7108        7108   s7109    Movie            최강전사 미니특공대 : 영웅의 탄생
#
#                          director  \
# 2036                       Cho Il
# 2304  Sabina Fedeli, Anna Migotto
# 2666                          NaN
# 5972             Michael Margolis
# ...

# %%
happy = pd.read_csv("data/world-happiness-report-2021.csv")

# %%
happy
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
happy
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
happy = pd.read_csv("data/world-happiness-report-2021.csv")

# %%
happy
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
happy.set_index("Country name", inplace = True)

# %%
happy
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
happy.sort_index()
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Afghanistan                           South Asia         2.523
# Albania               Central and Eastern Europe         5.117
# Algeria             Middle East and North Africa         4.887
# Argentina            Latin America and Caribbean         5.929
# Armenia       Commonwealth of Independent States         5.283
# ...                                          ...           ...
# Venezuela            Latin America and Caribbean         4.892
# Vietnam                           Southeast Asia         5.411
# Yemen               Middle East and North Africa         3.658
# Zambia                        Sub-Saharan Africa         4.073
# Zimbabwe                      Sub-Saharan Africa         3.145
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Afghanistan                            0.038         2.596         2.449
# ...

# %%
happy.sort_index(ascending = False, inplace = True)

# %%
happy
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Zimbabwe                      Sub-Saharan Africa         3.145
# Zambia                        Sub-Saharan Africa         4.073
# Yemen               Middle East and North Africa         3.658
# Vietnam                           Southeast Asia         5.411
# Venezuela            Latin America and Caribbean         4.892
# ...                                          ...           ...
# Armenia       Commonwealth of Independent States         5.283
# Argentina            Latin America and Caribbean         5.929
# Algeria             Middle East and North Africa         4.887
# Albania               Central and Eastern Europe         5.117
# Afghanistan                           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Zimbabwe                               0.058         3.259         3.030
# ...

# %%
happy.loc["Yemen"]
# Out:
# Regional indicator                            Middle East and North Africa
# Ladder score                                                         3.658
# Standard error of ladder score                                        0.07
# upperwhisker                                                         3.794
# lowerwhisker                                                         3.521
# Logged GDP per capita                                                7.578
# Social support                                                       0.832
# Healthy life expectancy                                             57.122
# Freedom to make life choices                                         0.602
# Generosity                                                          -0.147
# Perceptions of corruption                                              0.8
# Ladder score in Dystopia                                              2.43
# ...

# %% [markdown]
# # Better way of representation than the above

# %%
happy.loc[["Yemen"]]
# Out:
#                         Regional indicator  Ladder score  \
# Country name
# Yemen         Middle East and North Africa         3.658
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Yemen                                   0.07         3.794         3.521
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Yemen                         7.578           0.832                   57.122
#
#               Freedom to make life choices  Generosity  \
# Country name
# Yemen                                0.602      -0.147
#
#               Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# Yemen                               0.8                      2.43
#
#               Explained by: Log GDP per capita  Explained by: Social support  \
# Country name
# Yemen                                    0.329                         0.831
#
# ...

# %%
happy.loc[["Yemen", "Canada", "Mexico", "India"]]
# Out:
#                         Regional indicator  Ladder score  \
# Country name
# Yemen         Middle East and North Africa         3.658
# Canada               North America and ANZ         7.103
# Mexico         Latin America and Caribbean         6.317
# India                           South Asia         3.819
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Yemen                                  0.070         3.794         3.521
# Canada                                 0.042         7.185         7.021
# Mexico                                 0.053         6.420         6.213
# India                                  0.026         3.869         3.769
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Yemen                         7.578           0.832                   57.122
# Canada                       10.776           0.926                   73.800
# ...

# %%
house
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
house.loc[5 : 10]
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 5   7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6   1321400060  20140627T000000   257500.0         3       2.25         1715
# 7   2008000270  20150115T000000   291850.0         3       1.50         1060
# 8   2414600126  20150415T000000   229500.0         3       1.00         1780
# 9   3793500160  20150312T000000   323000.0         3       2.50         1890
# 10  1736800520  20150403T000000   662500.0         3       2.50         3560
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 5     101930     1.0           0     0  ...     11        3890           1530
# 6       6819     2.0           0     0  ...      7        1715              0
# 7       9711     1.0           0     0  ...      7        1060              0
# 8       7470     1.0           0     0  ...      7        1050            730
# ...

# %%
house.loc[5 : 10 : 2]
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 5  7237550310  20140512T000000  1225000.0         4        4.5         5420
# 7  2008000270  20150115T000000   291850.0         3        1.5         1060
# 9  3793500160  20150312T000000   323000.0         3        2.5         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 5    101930     1.0           0     0  ...     11        3890           1530
# 7      9711     1.0           0     0  ...      7        1060              0
# 9      6560     2.0           0     0  ...      7        1890              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 5      2001             0    98053  47.6561 -122.005           4760
# 7      1963             0    98198  47.4095 -122.315           1650
# 9      2003             0    98038  47.3684 -122.031           2390
#
#    sqft_lot15
# 5      101930
# 7        9711
# 9        7570
#
# ...

# %%
happy.loc["Yemen":"Vietnam"]
# Out:
#                         Regional indicator  Ladder score  \
# Country name
# Yemen         Middle East and North Africa         3.658
# Vietnam                     Southeast Asia         5.411
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Yemen                                  0.070         3.794         3.521
# Vietnam                                0.039         5.488         5.334
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Yemen                         7.578           0.832                   57.122
# Vietnam                       8.973           0.850                   68.034
#
#               Freedom to make life choices  Generosity  \
# Country name
# Yemen                                0.602      -0.147
# Vietnam                              0.940      -0.098
#
#               Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# ...

# %%
happy.loc["Zimbawe":"Vietnam"]
# Out:
#                         Regional indicator  Ladder score  \
# Country name
# Zimbabwe                Sub-Saharan Africa         3.145
# Zambia                  Sub-Saharan Africa         4.073
# Yemen         Middle East and North Africa         3.658
# Vietnam                     Southeast Asia         5.411
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Zimbabwe                               0.058         3.259         3.030
# Zambia                                 0.069         4.209         3.938
# Yemen                                  0.070         3.794         3.521
# Vietnam                                0.039         5.488         5.334
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Zimbabwe                      7.943           0.750                   56.201
# Zambia                        8.145           0.708                   55.809
# ...

# %%
happy.loc["Zimbawe":"Venezuela":2]
# Out:
#                         Regional indicator  Ladder score  \
# Country name
# Zimbabwe                Sub-Saharan Africa         3.145
# Yemen         Middle East and North Africa         3.658
# Venezuela      Latin America and Caribbean         4.892
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Zimbabwe                               0.058         3.259         3.030
# Yemen                                  0.070         3.794         3.521
# Venezuela                              0.064         5.017         4.767
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Zimbabwe                      7.943           0.750                   56.201
# Yemen                         7.578           0.832                   57.122
# Venezuela                     9.073           0.861                   66.700
#
#               Freedom to make life choices  Generosity  \
# Country name
# ...

# %%
happy
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Zimbabwe                      Sub-Saharan Africa         3.145
# Zambia                        Sub-Saharan Africa         4.073
# Yemen               Middle East and North Africa         3.658
# Vietnam                           Southeast Asia         5.411
# Venezuela            Latin America and Caribbean         4.892
# ...                                          ...           ...
# Armenia       Commonwealth of Independent States         5.283
# Argentina            Latin America and Caribbean         5.929
# Algeria             Middle East and North Africa         4.887
# Albania               Central and Eastern Europe         5.117
# Afghanistan                           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Zimbabwe                               0.058         3.259         3.030
# ...

# %%
happy.iloc[[0]]
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Zimbabwe      Sub-Saharan Africa         3.145
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Zimbabwe                               0.058         3.259          3.03
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Zimbabwe                      7.943            0.75                   56.201
#
#               Freedom to make life choices  Generosity  \
# Country name
# Zimbabwe                             0.677      -0.047
#
#               Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# Zimbabwe                          0.821                      2.43
#
#               Explained by: Log GDP per capita  Explained by: Social support  \
# Country name
# Zimbabwe                                 0.457                         0.649
#
#               Explained by: Healthy life expectancy  \
# ...

# %%
happy.iloc[[0, 10, 20, 30, 40, 50]]
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Zimbabwe                      Sub-Saharan Africa         3.145
# Ukraine       Commonwealth of Independent States         4.875
# Switzerland                       Western Europe         7.571
# Sierra Leone                  Sub-Saharan Africa         3.849
# Peru                 Latin America and Caribbean         5.840
# Nicaragua            Latin America and Caribbean         5.972
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Zimbabwe                               0.058         3.259         3.030
# Ukraine                                0.052         4.977         4.773
# Switzerland                            0.036         7.643         7.500
# Sierra Leone                           0.077         4.001         3.698
# Peru                                   0.075         5.988         5.692
# ...

# %%
happy.iloc[10:30]
# Out:
#                                           Regional indicator  Ladder score  \
# Country name
# Ukraine                   Commonwealth of Independent States         4.875
# Uganda                                    Sub-Saharan Africa         4.636
# Turkmenistan              Commonwealth of Independent States         5.066
# Turkey                          Middle East and North Africa         4.948
# Tunisia                         Middle East and North Africa         4.596
# Togo                                      Sub-Saharan Africa         4.107
# Thailand                                      Southeast Asia         5.985
# Tanzania                                  Sub-Saharan Africa         3.623
# Tajikistan                Commonwealth of Independent States         5.466
# Taiwan Province of China                           East Asia         6.584
# Switzerland                                   Western Europe         7.571
# ...

# %%
house
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
house.loc[100:200, ["price","bedrooms"]]
# Out:
#          price  bedrooms
# 100   850830.0         3
# 101   555000.0         3
# 102   699950.0         3
# 103  1088000.0         3
# 104   290000.0         3
# ..         ...       ...
# 196   423000.0         4
# 197   465000.0         3
# 198   440000.0         3
# 199   385000.0         3
# 200   210000.0         3
#
# [101 rows x 2 columns]

# %%
house.loc[100:200:2, ["price","bedrooms"]]
# Out:
#         price  bedrooms
# 100  850830.0         3
# 102  699950.0         3
# 104  290000.0         3
# 106  460000.0         3
# 108  680000.0         4
# 110  597750.0         4
# 112  272500.0         3
# 114  480000.0         4
# 116  518500.0         3
# 118  171800.0         4
# 120  660000.0         3
# 122  395000.0         2
# 124  770000.0         3
# 126  445000.0         3
# 128  822500.0         5
# 130  212000.0         3
# 132  784000.0         3
# 134  675000.0         4
# 136  220000.0         4
# 138  382500.0         2
# 140  665000.0         2
# 142  205000.0         3
# 144  500000.0         4
# 146  890000.0         4
# 148  258000.0         5
# 150  532170.0         3
# 152  282950.0         3
# 154  350000.0         1
# 156  650000.0         5
# 158  247000.0         3
# 160  255000.0         5
# 162  900000.0         3
# 164  420000.0         3
# 166  269950.0         2
# 168  653000.0         3
# 170  284000.0         3
# 172  313000.0         3
# ...

# %%
house["bedrooms"].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
house["bedrooms"].value_counts().loc[0]
# Out:
# 13

# %%
house["bedrooms"].value_counts().iloc[0]
# Out:
# 9824

# %%
house["bedrooms"].value_counts().sort_index()
# Out:
# 0       13
# 1      199
# 2     2760
# 3     9824
# 4     6882
# 5     1601
# 6      272
# 7       38
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
house["bedrooms"].value_counts().sort_index().iloc[0]
# Out:
# 13
